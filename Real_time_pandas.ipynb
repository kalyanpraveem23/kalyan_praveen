# %%
import pandas as pd

# %%
Order_details=pd.read_csv("data.tsv - Copy.txt",sep="@")
Order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### 1.1 perform Initial Analysis

# %%
Order_details.shape
# Out:
# (4622, 5)

# %%
Order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
Order_details.isnull().sum() # chain of function
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
Order_details.describe(include = "all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ### Find out the items sold  in the restaurent

# %%
Order_details.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
Order_details['item_name'].nunique()
# Out:
# 50

# %%
Order_details['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
Order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
Order_details.groupby("item_name")['quantity'].sum().sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %% [markdown]
# ## Chapter 3 - Pandas Data structure
#
# * 1D - Series
# * 2D - Dataframe

# %%
pd.Series(data=[1,2,'$5.6'])
# Out:
# 0       1
# 1       2
# 2    $5.6
# dtype: object

# %%
pd.DataFrame(data={"Name":["Praveen","Kalyan","Tharushiya","Sai"],
                  "Math_marks":["100",'95','99','32'],
                   "Science_marks":['100','94','88','98']})
# Out:
#          Name Math_marks Science_marks
# 0     Praveen        100           100
# 1      Kalyan         95            94
# 2  Tharushiya         99            88
# 3         Sai         32            98

# %%
pd.Series(data=[2.4,5.43,6.66,'Kalyan'])
# Out:
# 0       2.4
# 1      5.43
# 2      6.66
# 3    Kalyan
# dtype: object

# %%
pd.DataFrame(data={"Name":["Praveen","Kalyan","Tharushiya","Sai","Madesh"],
                   "Math_marks":["100",'95','99','32','77'],
                   "Science_marks":['100','94','88','98','45'],
                   "Tamil_marks":['77','88','67','99','88'],
                   "English_marks":['99','100','88','89','69']})
# Out:
#          Name Math_marks Science_marks Tamil_marks English_marks
# 0     Praveen        100           100          77            99
# 1      Kalyan         95            94          88           100
# 2  Tharushiya         99            88          67            88
# 3         Sai         32            98          99            89
# 4      Madesh         77            45          88            69

# %% [markdown]
# ## Flitering and Selection & Sorting

# %%
Euro_2012_Data=pd.read_csv("Euro_2012_stats_TEAM.csv")
Euro_2012_Data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
Euro_2012_Data[['Team','Goals']]
# Out:
#                    Team  Goals
# 0               Croatia      4
# 1        Czech Republic      4
# 2               Denmark      4
# 3               England      5
# 4                France      3
# 5               Germany     10
# 6                Greece      5
# 7                 Italy      6
# 8           Netherlands      2
# 9                Poland      2
# 10             Portugal      6
# 11  Republic of Ireland      1
# 12               Russia      5
# 13                Spain     12
# 14               Sweden      5
# 15              Ukraine      2

# %%
Fliter_euro_data=Euro_2012_Data[['Team','Goals','Yellow Cards','Red Cards']]
Fliter_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
Fliter_euro_data.sort_values(by="Yellow Cards",ascending = False).head()
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0
# 0    Croatia      4             9          0
# 6     Greece      5             9          1

# %%
Fliter_euro_data[Fliter_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %%
Fliter_euro_data[Fliter_euro_data["Yellow Cards"] >=8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %%
Fliter_euro_data[Fliter_euro_data["Yellow Cards"] <=4]
# Out:
#       Team  Goals  Yellow Cards  Red Cards
# 2  Denmark      4             4          0
# 5  Germany     10             4          0

# %%
Fliter_euro_data[Fliter_euro_data["Goals"] <=4]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 4                France      3             6          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1
# 15              Ukraine      2             5          0

# %%
Fliter_euro_data[Fliter_euro_data["Goals"] >=10]
# Out:
#        Team  Goals  Yellow Cards  Red Cards
# 5   Germany     10             4          0
# 13    Spain     12            11          0

# %% [markdown]
# ## How to deal with missing  values
