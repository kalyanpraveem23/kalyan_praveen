# %%
import pandas as pd

# %%
data=pd.read_csv("data_clean.csv")

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
data.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
data.drop(columns=['Unnamed: 0'])
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
del data['Unnamed: 0']

# %%
data.isna().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Temp C      0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
data["Ozone"]
# Out:
# 0      41.0
# 1      36.0
# 2      12.0
# 3      18.0
# 4       NaN
#        ...
# 153    41.0
# 154    30.0
# 155     NaN
# 156    14.0
# 157    18.0
# Name: Ozone, Length: 158, dtype: float64

# %%
data["Ozone"].mean()
# Out:
# np.float64(41.583333333333336)

# %%
data["Ozone"]=data["Ozone"].fillna(data["Ozone"].mean())

# %%
data
# Out:
#          Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.000000    190.0   7.4     67     5    1  2010    67       S
# 1    36.000000    118.0   8.0     72     5    2  2010    72       C
# 2    12.000000    149.0  12.6     74     5    3  2010    74      PS
# 3    18.000000    313.0  11.5     62     5    4  2010    62       S
# 4    41.583333      NaN  14.3     56     5    5  2010    56       S
# ..         ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153  41.000000    190.0   7.4     67     5    1  2010    67       C
# 154  30.000000    193.0   6.9     70     9   26  2010    70      PS
# 155  41.583333    145.0  13.2     77     9   27  2010    77       S
# 156  14.000000    191.0  14.3     75     9   28  2010    75       S
# 157  18.000000    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data["Solar.R"]
# Out:
# 0      190.0
# 1      118.0
# 2      149.0
# 3      313.0
# 4        NaN
#        ...
# 153    190.0
# 154    193.0
# 155    145.0
# 156    191.0
# 157    131.0
# Name: Solar.R, Length: 158, dtype: float64

# %%
data["Solar.R"].mean()
# Out:
# np.float64(185.40397350993376)

# %%
data["Solar.R"]=data['Solar.R'].fillna(Weather_data["Solar.R"].mean())

# %%
data
# Out:
#          Ozone     Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4     67     5    1  2010    67       S
# 1    36.000000  118.000000   8.0     72     5    2  2010    72       C
# 2    12.000000  149.000000  12.6     74     5    3  2010    74      PS
# 3    18.000000  313.000000  11.5     62     5    4  2010    62       S
# 4    41.583333  185.403974  14.3     56     5    5  2010    56       S
# ..         ...         ...   ...    ...   ...  ...   ...   ...     ...
# 153  41.000000  190.000000   7.4     67     5    1  2010    67       C
# 154  30.000000  193.000000   6.9     70     9   26  2010    70      PS
# 155  41.583333  145.000000  13.2     77     9   27  2010    77       S
# 156  14.000000  191.000000  14.3     75     9   28  2010    75       S
# 157  18.000000  131.000000   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data.head(20)
# Out:
#         Ozone     Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0   41.000000  190.000000   7.4     67     5    1  2010    67       S
# 1   36.000000  118.000000   8.0     72     5    2  2010    72       C
# 2   12.000000  149.000000  12.6     74     5    3  2010    74      PS
# 3   18.000000  313.000000  11.5     62     5    4  2010    62       S
# 4   41.583333  185.403974  14.3     56     5    5  2010    56       S
# 5   28.000000  185.403974  14.9     66     5    6  2010    66       C
# 6   23.000000  299.000000   8.6     65     5    7  2010    65      PS
# 7   19.000000   99.000000  13.8     59     5    8  2010    59       C
# 8    8.000000   19.000000  20.1     61     5    9  2010    61      PS
# 9   41.583333  194.000000   8.6     69     5   10  2010    69       S
# 10   7.000000  185.403974   6.9      C     5   11  2010    74       C
# 11  16.000000  256.000000   9.7     69     5   12  2010    69      PS
# ...

# %%
data['Weather'].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %%
data['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
data['Weather'] = data['Weather'].fillna(data['Weather'].mode()[0])

# %%
data
# Out:
#          Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.000000    190.0   7.4     67     5    1  2010    67       S
# 1    36.000000    118.0   8.0     72     5    2  2010    72       C
# 2    12.000000    149.0  12.6     74     5    3  2010    74      PS
# 3    18.000000    313.0  11.5     62     5    4  2010    62       S
# 4    41.583333      NaN  14.3     56     5    5  2010    56       S
# ..         ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153  41.000000    190.0   7.4     67     5    1  2010    67       C
# 154  30.000000    193.0   6.9     70     9   26  2010    70      PS
# 155  41.583333    145.0  13.2     77     9   27  2010    77       S
# 156  14.000000    191.0  14.3     75     9   28  2010    75       S
# 157  18.000000    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
data["Month"].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
data[data["Month"]=="May"]
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 23   32.0     92.0  12.0     61   May   24  2010    61       C

# %%
data['Month']=data['Month'].replace( to_replace="May",value=5)

# %%
data['Month'].head(30)
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    5
# Name: Month, dtype: object

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data['Month'].unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
data['Month']=data['Month'].astype(int)

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
del data ['Temp C']

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
# Label Encoding
# one hot Encoding

# %%
df_1=data.copy()

# %%
df_2=data.copy()

# %%
df_1
# Out:
#          Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    41.000000    190.0   7.4      5    1  2010    67       S
# 1    36.000000    118.0   8.0      5    2  2010    72       C
# 2    12.000000    149.0  12.6      5    3  2010    74      PS
# 3    18.000000    313.0  11.5      5    4  2010    62       S
# 4    41.583333      NaN  14.3      5    5  2010    56       S
# ..         ...      ...   ...    ...  ...   ...   ...     ...
# 153  41.000000    190.0   7.4      5    1  2010    67       C
# 154  30.000000    193.0   6.9      9   26  2010    70      PS
# 155  41.583333    145.0  13.2      9   27  2010    77       S
# 156  14.000000    191.0  14.3      9   28  2010    75       S
# 157  18.000000    131.0   8.0      9   29  2010    76       C
#
# [158 rows x 8 columns]

# %% [markdown]
# ## Label encoding

# %%
from sklearn.preprocessing  import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_1["Weather"]=le.fit_transform(df_1["Weather"])

# %%
df_1["Weather"]
# Out:
# 0      2
# 1      0
# 2      1
# 3      2
# 4      2
#       ..
# 153    0
# 154    1
# 155    2
# 156    2
# 157    0
# Name: Weather, Length: 158, dtype: int64

# %%
df_1
# Out:
#          Ozone  Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0    41.000000    190.0   7.4      5    1  2010    67        2
# 1    36.000000    118.0   8.0      5    2  2010    72        0
# 2    12.000000    149.0  12.6      5    3  2010    74        1
# 3    18.000000    313.0  11.5      5    4  2010    62        2
# 4    41.583333      NaN  14.3      5    5  2010    56        2
# ..         ...      ...   ...    ...  ...   ...   ...      ...
# 153  41.000000    190.0   7.4      5    1  2010    67        0
# 154  30.000000    193.0   6.9      9   26  2010    70        1
# 155  41.583333    145.0  13.2      9   27  2010    77        2
# 156  14.000000    191.0  14.3      9   28  2010    75        2
# 157  18.000000    131.0   8.0      9   29  2010    76        0
#
# [158 rows x 8 columns]

# %% [markdown]
# ## One hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
One_HotEncoder=OneHotEncoder()

# %%
df_2["Weather"].unique()
# Out:
# array(['S', 'C', 'PS'], dtype=object)

# %%
df_2[["C","S","PS"]]=One_HotEncoder.fit_transform(df_2[["Weather"]]).toarray()

# %%
df_2
# Out:
#          Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather    C    S   PS
# 0    41.000000    190.0   7.4      5    1  2010    67       S  0.0  0.0  1.0
# 1    36.000000    118.0   8.0      5    2  2010    72       C  1.0  0.0  0.0
# 2    12.000000    149.0  12.6      5    3  2010    74      PS  0.0  1.0  0.0
# 3    18.000000    313.0  11.5      5    4  2010    62       S  0.0  0.0  1.0
# 4    41.583333      NaN  14.3      5    5  2010    56       S  0.0  0.0  1.0
# ..         ...      ...   ...    ...  ...   ...   ...     ...  ...  ...  ...
# 153  41.000000    190.0   7.4      5    1  2010    67       C  1.0  0.0  0.0
# 154  30.000000    193.0   6.9      9   26  2010    70      PS  0.0  1.0  0.0
# 155  41.583333    145.0  13.2      9   27  2010    77       S  0.0  0.0  1.0
# 156  14.000000    191.0  14.3      9   28  2010    75       S  0.0  0.0  1.0
# 157  18.000000    131.0   8.0      9   29  2010    76       C  1.0  0.0  0.0
#
# [158 rows x 11 columns]
