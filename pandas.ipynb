# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install --upgrade pip

# %%
import pandas as pd

# %%
order_df = pd.read_csv("data.tsv.txt",sep="@")

# %%
order_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
sales_2017=pd.read_csv('Sales Transactions-2017.csv')

# %%
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# # EDA

# %%
order_df.shape
# Out:
# (4622, 5)

# %%
order_df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order_df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
order_df.head(15)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
order_df.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
order_df['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
order_df['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
order_df['item_price'].unique()
# Out:
# array(['$2.39 ', '$3.39 ', '$16.98 ', '$10.98 ', '$1.69 ', '$11.75 ',
#        '$9.25 ', '$4.45 ', '$8.75 ', '$11.25 ', '$8.49 ', '$2.18 ',
#        '$8.99 ', '$1.09 ', '$2.95 ', '$2.15 ', '$3.99 ', '$22.50 ',
#        '$11.48 ', '$17.98 ', '$17.50 ', '$4.30 ', '$5.90 ', '$1.25 ',
#        '$23.78 ', '$6.49 ', '$11.08 ', '$1.50 ', '$22.16 ', '$32.94 ',
#        '$22.20 ', '$10.58 ', '$2.50 ', '$23.50 ', '$7.40 ', '$18.50 ',
#        '$3.00 ', '$6.78 ', '$11.89 ', '$9.39 ', '$4.00 ', '$3.75 ',
#        '$8.69 ', '$2.29 ', '$8.90 ', '$3.27 ', '$3.89 ', '$8.19 ',
#        '$35.00 ', '$27.75 ', '$11.80 ', '$6.00 ', '$26.25 ', '$21.96 ',
#        '$4.36 ', '$7.50 ', '$4.78 ', '$13.35 ', '$6.45 ', '$5.07 ',
#        '$22.96 ', '$7.17 ', '$7.98 ', '$4.50 ', '$26.07 ', '$12.98 ',
#        '$35.25 ', '$44.25 ', '$10.50 ', '$33.75 ', '$16.38 ', '$13.52 ',
#        '$5.00 ', '$15.00 ', '$8.50 ', '$17.80 ', '$1.99 ', '$11.49 '],
#       dtype=object)

# %%
len(order_df['item_price'].unique())
# Out:
# 78

# %%
order_df['choice_description'].nunique()
# Out:
# 1043

# %%
order_df['item_name'].value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
order_df['item_name'].value_counts().head()
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Name: count, dtype: int64

# %%
order_df['item_name'].value_counts().tail()
# Out:
# item_name
# Salad                                2
# Bowl                                 2
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Carnitas Salad                       1
# Name: count, dtype: int64

# %%
football_df=pd.read_csv('Euro_2012_stats_TEAM.csv')

# %%
football_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_df.shape
# Out:
# (16, 35)

# %%
football_df.dtypes
# Out:
# Team                           object
# Goals                           int64
# Shots on target                 int64
# Shots off target                int64
# Shooting Accuracy              object
# % Goals-to-shots               object
# Total shots (inc. Blocked)      int64
# Hit Woodwork                    int64
# Penalty goals                   int64
# Penalties not scored            int64
# Headed goals                    int64
# Passes                          int64
# Passes completed                int64
# Passing Accuracy               object
# Touches                         int64
# Crosses                         int64
# Dribbles                        int64
# Corners Taken                   int64
# Tackles                         int64
# Clearances                      int64
# Interceptions                   int64
# Clearances off line           float64
# Clean Sheets                    int64
# Blocks                          int64
# Goals conceded                  int64
# ...

# %%
football_df.isna().sum()
# Out:
# Team                          0
# Goals                         0
# Shots on target               0
# Shots off target              0
# Shooting Accuracy             0
# % Goals-to-shots              0
# Total shots (inc. Blocked)    0
# Hit Woodwork                  0
# Penalty goals                 0
# Penalties not scored          0
# Headed goals                  0
# Passes                        0
# Passes completed              0
# Passing Accuracy              0
# Touches                       0
# Crosses                       0
# Dribbles                      0
# Corners Taken                 0
# Tackles                       0
# Clearances                    0
# Interceptions                 0
# Clearances off line           1
# Clean Sheets                  0
# Blocks                        0
# Goals conceded                0
# Saves made                    0
# Saves-to-shots ratio          0
# Fouls Won                     0
# Fouls Conceded                0
# ...

# %%
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
football_df['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
football_df['Goals']>5
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# Name: Goals, dtype: bool

# %%
football_df[football_df['Goals']>5]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# ...

# %%
football_df[football_df['Shots on target']<20]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 6                Greece      5                8                18
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# ...

# %%
football_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_df[['Team','Goals','Yellow Cards','Red Cards']]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
football_df[football_df['Team']=='France']
# Out:
#      Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 4  France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 4             6.5%                          65             1              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 4                     0  ...           6                 54.6%         36
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 4             51         5             6          0       11        11
#
#    Players Used
# 4            19
#
# [1 rows x 35 columns]

# %%
football_df.sort_values(by='Goals',ascending=False)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 13                Spain     12               42                33
# 5               Germany     10               32                32
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 3               England      5               11                18
# 6                Greece      5                8                18
# 12               Russia      5                9                31
# 14               Sweden      5               17                19
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 4                France      3               22                24
# 8           Netherlands      2               12                36
# ...

# %%
football_df.sort_values(by='Fouls Won',ascending=False)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 13                Spain     12               42                33
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 6                Greece      5                8                18
# 5               Germany     10               32                32
# 1        Czech Republic      4               13                18
# 9                Poland      2               15                23
# 15              Ukraine      2                7                26
# 3               England      5               11                18
# 11  Republic of Ireland      1                7                12
# 0               Croatia      4               13                12
# 4                France      3               22                24
# 8           Netherlands      2               12                36
# ...

# %%
football_df[(football_df['Yellow Cards']>8) & (football_df['Goals']>5)]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 7                      0  ...          20                 74.1%        101
# 10                     0  ...          10                 71.5%         73
# 13                     0  ...          15                 93.8%        102
#
# ...

# %%
football_df[(football_df['Goals']>2) & (football_df['Yellow Cards']<10)]
# Out:
#               Team  Goals  Shots on target  Shots off target  \
# 0          Croatia      4               13                12
# 1   Czech Republic      4               13                18
# 2          Denmark      4               10                10
# 3          England      5               11                18
# 4           France      3               22                24
# 5          Germany     10               32                32
# 6           Greece      5                8                18
# 12          Russia      5                9                31
# 14          Sweden      5               17                19
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# ...

# %%
football_df.iloc[0:14,0:4]
# Out:
#                    Team  Goals  Shots on target  Shots off target
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_df.loc[[1,2,3],['Goals','Team']]
# Out:
#    Goals            Team
# 1      4  Czech Republic
# 2      4         Denmark
# 3      5         England

# %%
football_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
del football_df['Shots on target']

# %%
football_df
# Out:
#                    Team  Goals  Shots off target Shooting Accuracy  \
# 0               Croatia      4                12             51.9%
# 1        Czech Republic      4                18             41.9%
# 2               Denmark      4                10             50.0%
# 3               England      5                18             50.0%
# 4                France      3                24             37.9%
# 5               Germany     10                32             47.8%
# 6                Greece      5                18             30.7%
# 7                 Italy      6                45             43.0%
# 8           Netherlands      2                36             25.0%
# 9                Poland      2                23             39.4%
# 10             Portugal      6                42             34.3%
# 11  Republic of Ireland      1                12             36.8%
# 12               Russia      5                31             22.5%
# ...

# %%
football_df=football_df.drop(labels='Hit Woodwork',axis=1)

# %%
football_df
# Out:
#                    Team  Goals  Shots off target Shooting Accuracy  \
# 0               Croatia      4                12             51.9%
# 1        Czech Republic      4                18             41.9%
# 2               Denmark      4                10             50.0%
# 3               England      5                18             50.0%
# 4                France      3                24             37.9%
# 5               Germany     10                32             47.8%
# 6                Greece      5                18             30.7%
# 7                 Italy      6                45             43.0%
# 8           Netherlands      2                36             25.0%
# 9                Poland      2                23             39.4%
# 10             Portugal      6                42             34.3%
# 11  Republic of Ireland      1                12             36.8%
# 12               Russia      5                31             22.5%
# ...

# %%
MOD = 10**9 + 7

def count_divisors(n):
    count = 0
    i = 1
    while i * i <= n:
        if n % i == 0:
            count += 1
            if i != n // i:
                count += 1
        i += 1
    return count

def get_count(N, X, A):
    dp = [0] * (N + 1)
    dp[0] = 1

    for i in range(1, N + 1):
        product = 1
        for j in range(i, 0, -1):
            product *= A[j - 1]
            if product > 1e12:
                break
            if count_divisors(product) >= X:
                dp[i] = (dp[i] + dp[j - 1]) % MOD
    return dp[N]

N = 3
X = 5
A = [2, 6, 8]
print(get_count(N, X, A))

N2 = 2
X2 = 2
A2 = [2, 2]
print(get_count(N2, X2, A2))
# Out:
# 1
# 2

# %%
MOD = 10**9 + 7

# Memoization dictionary for divisor counts
divisor_cache = {}

def count_divisors(n):
    if n in divisor_cache:
        return divisor_cache[n]
    count = 0
    i = 1
    while i * i <= n:
        if n % i == 0:
            count += 1
            if i != n // i:
                count += 1
        i += 1
    divisor_cache[n] = count
    return count

def get_count(N, X, A):
    dp = [0] * (N + 1)
    dp[0] = 1

    for i in range(1, N + 1):
        product = 1
        for j in range(i, 0, -1):
            product *= A[j - 1]
            if product > 1e12:
                break
            if count_divisors(product) >= X:
                dp[i] = (dp[i] + dp[j - 1]) % MOD
    return dp[N]

# Test cases
N = 3
X = 5
A = [2, 6, 8]
print(get_count(N, X, A))

N2 = 2
X2 = 2
A2 = [2, 2]
print(get_count(N2, X2, A2))
# Out:
# 1
# 2

# %%
MOD = 10**9 + 7

def get_count(n, x, a):
    memo = {}
    def dfs(idx):
        if idx == n:
            return 1
        if idx in memo:
            return memo[idx]

        res = 0
        prod = 1
        for j in range(idx, n):
            prod *= a[j]
            if prod > 1e12:  # Optional cutoff
                break
            if count_factors(prod) >= x:
                res = (res + dfs(j + 1)) % MOD
        memo[idx] = res
        return res

    return dfs(0)

def count_factors(num):
    cnt = 0
    i = 1
    while i * i <= num:
        if num % i == 0:
            cnt += 1
            if i != num // i:
                cnt += 1
        i += 1
    return cnt

# Example usage:
n1, x1, a1 = 3, 5, [2, 6, 8]
print(get_count(n1, x1, a1))  # Output: 1

n2, x2, a2 = 2, 2, [2, 2]
print(get_count(n2, x2, a2))  # Output: 2
# Out:
# 1
# 2

# %%
MOD = int(1e9) + 7

def get_count(n, x, a):
    memo = {}

    def dfs(idx):
        if idx == n:
            return 1
        if idx in memo:
            return memo[idx]

        res = 0
        prod = 1
        for j in range(idx, n):
            prod *= a[j]
            if prod > 1e12:  
                break
            if count_factors(prod) >= x:
                res = (res + dfs(j + 1)) % MOD

        memo[idx] = res
        return res

    return dfs(0)

def count_factors(num):
    cnt = 0
    i = 1
    while i * i <= num:
        if num % i == 0:
            cnt += 1
            if i != num // i:
                cnt += 1
        i += 1
    return cnt


if __name__ == "__main__":
    n, x = map(int, input().split())
    a = list(map(int, input().split()))
    print(get_count(n, x, a))
# Out:
#  3 5
#  2 6 8
# 1
